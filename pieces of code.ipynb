# %% [markdown]
# # How to pronounce “Jupyter” in “Jupyter Notebook”?
#
# let's listen to Fernando Perez (https://bids.berkeley.edu/people/fernando-p%C3%A9rez)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('cc2hHjARNTY?start=338')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/cc2hHjARNTY?start=338"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # examples

# %% [markdown]
# ## Progress bar

# %%
from tqdm import tqdm
from time import sleep

# %%
#!pip install tqdm
pbar = tqdm(total=16)
for i in range(16):
    sleep(0.1)
    pbar.update(1)
pbar.close()
# Out:
# 100%|██████████| 16/16 [00:01<00:00,  9.80it/s]

# %% [markdown]
# ## Notify after done

# %%
#!pip install jupyternotify
import jupyternotify
ip = get_ipython()
ip.register_magics(jupyternotify.JupyterNotifyMagics)

# %%
# %%notify
# import time
# time.sleep(5)

# %% [markdown]
# ## plot high resolution plot

# %%
import matplotlib.pyplot as plt
x = range(1000)
y = [i ** 2 for i in x]
plt.plot(x,y)
plt.show();

# %%
# %config InlineBackend.figure_format ='retina'
plt.plot(x,y)
plt.show();

# %% [markdown]
# ## Multicursor
#
# Jupyter supports mutiple cursors, similar to Sublime Text. Simply click and drag your mouse while holding down Alt.

# %%
x=[
    one,
    two,
    three,
    four,
]

# %% [markdown]
# ## Parallel
# https://github.com/ipython/ipyparallel

# %% [markdown]
# ## ; and fancy plot

# %%
# %pylab inline 
#(import numpy as np and matplotlib)
plt.xkcd()
x = np.arange(0,2*np.pi,.01)
plt.plot(x,np.sin(x));
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## HTML

# %%
# from IPython.display import HTML
# s = """<marquee>Example Evelyn!!!</marquee>"""
# h = HTML(s); h

# %%
# %%HTML
# <button type="button" id="loading-example-btn" data-loading-text="Loading..." class="btn btn-primary">
#   Loading st
# Out:
# <button type="button" id="loading-example-btn" data-loading-text="Loading..." class="btn btn-primary">
#   Loading st

# %% [markdown]
# ## Debugger
#
# q quit

# %%
from IPython.core.debugger import set_trace

def add_to_life_universe_everything(x):
    answer = 42
#     set_trace()
    answer += x
    set_trace()
    return answer

add_to_life_universe_everything(12)
# Out:
# > /tmp/ipykernel_11112/301484359.py(8)add_to_life_universe_everything()
#       6     answer += x
#       7     set_trace()
# ----> 8     return answer
#       9
#      10 add_to_life_universe_everything(12)
#
# ipdb> q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# /tmp/ipykernel_11112/301484359.py in <module>
#       8     return answer
#       9
# ---> 10 add_to_life_universe_everything(12)
#
# /tmp/ipykernel_11112/301484359.py in add_to_life_universe_everything(x)
#       6     answer += x
#       7     set_trace()
# ----> 8     return answer
#       9
#      10 add_to_life_universe_everything(12)
#
# /tmp/ipykernel_11112/301484359.py in add_to_life_universe_everything(x)
#       6     answer += x
#       7     set_trace()
# ----> 8     return answer
#       9
#      10 add_to_life_universe_everything(12)
#
# ...

# %% [markdown]
# ## humor

# %%
# import antigravity
import antigravity

# def main():
#     antigravity.geohash()

# if __name__ == '__main__':
#     main()

# %%
# !pip install py-heat-magic
# %load_ext heat

# %%
# %%heat
# # %prun
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# tips = sns.load_dataset("tips")  # Load data
#
# fig, axs = plt.subplots(1, 2)  # Create subplots
#
# # Boxplot with matplotlib
# tips_box = [tips.query('day == @day')['total_bill'] for day in tips.day.unique()]
# axs[0].boxplot(tips_box, labels=tips.day.unique())
#
# # Boxplot with Seaborn
# sns.boxplot(x="day", y="total_bill", data=tips, ax=axs[1])
#
# fig.suptitle('Boxplot', fontsize=18)  #
# plt.show()

# %%
# %whos
# Out:
# Variable                          Type         Data/Info
# --------------------------------------------------------
# add_to_life_universe_everything   function     <function add_to_life_uni<...>ything at 0x7fefde740320>
# antigravity                       module       <module 'antigravity' fro<...>ython3.7/antigravity.py'>
# axs                               ndarray      2: 2 elems, type `object`, 16 bytes
# fig                               Figure       Figure(432x288)
# main                              function     <function main at 0x7fefdd90c200>
# plt                               module       <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# set_trace                         function     <function set_trace at 0x7feff0803ef0>
# sns                               module       <module 'seaborn' from '/<...>ges/seaborn/__init__.py'>
# tips                              DataFrame         total_bill   tip    <...>n\n[244 rows x 7 columns]
# ...

# %% [markdown]
# ## Run the notebook from CLI
#
# Finally you can also execute your complete notebook from the command line interface using the below command

# %%
jupyter nbconvert --to notebook --execute <Notebook.ipynb>

# %%
# triangle_hist.py
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
if __name__ == '__main__':
    plt.hist(np.random.triangular(0, 5, 9, 1000), bins=100, linewidth=0)
    plt.show()

# %%
# %run triangle_hist.py
